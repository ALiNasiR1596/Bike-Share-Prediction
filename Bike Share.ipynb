# %% [markdown]
# ## Part 1: Clean the dataset and create graphs to explore the trend

# %%
#Ignoring all the warnings that come
import warnings
warnings.filterwarnings('ignore')

#Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns 
from sklearn.model_selection import train_test_split
from datetime import datetime
import statsmodels.formula.api as sm

#Load Data with pandas, and parse the first column into datetime

train = pd.read_csv("bikeshare.csv", parse_dates=[0])

# %% [markdown]
# # Data Fields
#
# - Datetime: hourly date + timestamp
# - Season: 1 = spring, 2 = summer, 3 = fall, 4 = winter
# - Holiday: whether the day is considered a holiday
# - Workingday: whether the day is neither a weekend nor holiday
# - Weather:
#           1: Clear, Few clouds, Partly cloudy, Partly cloudy
#           2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#           3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#           4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - Temp: temperature in Celsius
# - Atemp: "feels like" temperature in Celsius
# - Humidity: relative humidity
# - Windspeed: wind speed
# - Casual: number of non-registered user rentals initiated
# - Registered: number of registered user rentals initiated
# - Count: number of total rentals

# %%
#process the timestamp into year, month, hour and weekday
temp = pd.DatetimeIndex(train['datetime'])
train['year'] = temp.year
train['month'] = temp.month
train['hour'] = temp.hour
train['weekday'] = temp.weekday
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  hour  weekday
# 0        81        0.0       3          13     16  2011      1     0        5
# 1        80        0.0       8          32     40  2011      1     1        5
# 2        80        0.0       5          27     32  2011      1     2        5
# 3        75        0.0       3          10     13  2011      1     3        5
# 4        75        0.0       0           1      1  2011      1     4        5

# %%
#Define features vector

features = ['season', 'holiday', 'workingday', 'weather',
        'temp', 'atemp', 'humidity', 'windspeed', 'year',
         'month', 'weekday', 'hour']

# %%
#plot the histogram of rental count and log of rental count
rentals = train['count']

f, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist((rentals))
ax1.set_title('Histogram of rentals')
ax2.hist(np.log(rentals))
ax2.set_title('Histogram of log(rentals)')
# Out:
# Text(0.5, 1.0, 'Histogram of log(rentals)')

# %% [markdown]
# The rentals variable is distributed to be skewed to the right; while log(rentals) variable is distributed to be skewed to the left.

# %% [markdown]
# # Data Cleaning
#
# Two steps done to clean the data set:
#
# 1) As we can see the rentals distribution is skewed, as a first measure of data cleaning we remved the outliers from the dataset. Outliers were considered to be those values of rentals which were greater than I3+1.5*IQR.
#
# 2) Since the windspeed column has some zeros values associated with it, so we removed the rows where windspeed=0

# %%
rentals_describe = train['count'].describe()

IQR = rentals_describe['75%'] - rentals_describe['25%']
outlier = rentals_describe['75%'] + 1.5*IQR

train = train[train['count']<=outlier]

# Since we see that windspeed not much correlation with the rentals count and it has lot of zeros\
# so we can first anlyse the results by dropping the windspeed column

train = train[(train['windspeed'] != 0)]

# %%
#grouping by season, plot the box plot
season_group= (train.groupby("season"))["count"].sum()
season_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='season',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The count is lowest in spring and highest in fall. However, there are a lot of outliers in Winter and Spring.

# %%
#grouping by weekday, plot the box plot
weekday_group= (train.groupby("weekday"))["count"].sum()
weekday_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='weekday',data=train,width=0.5,palette="colorblind")
#deep,muted,pastel,bright,dark,colorblind,Blues,BuGn_r,GnBu_d
plt.show()

# %%
#seeing the difference between workday and non-workday
wd_group= (train.groupby("workingday"))["count"].sum()
wd_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='workingday',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# Count is pretty constant throughout the week. However, there are a lot of outliers from Monday to Friday and fewer during weekend.

# %%
#group by season and see the difference between holiday and non-holiday
sns.boxplot(y='count',x='holiday',data=train,hue="season",width=0.5,palette="colorblind")
# Out:
# <AxesSubplot:xlabel='holiday', ylabel='count'>

# %%
#seeing the difference between holiday and non-holiday
holiday_group= (train.groupby("holiday"))["count"].sum()
holiday_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='holiday',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# There is not much difference between holiday and non-holiday, except that there are outliers for non-holiday group.

# %%
#grouping by weather and plot the box plot
weather_group= (train.groupby("weather"))["count"].sum()
weather_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='weather',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The number of bikes rented decreases as the weather gets more severe.

# %%
#group by season and see the difference between the 2 years
sns.boxplot(y='count',x='year',data=train,hue='season',width=0.5,palette="colorblind")
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
#annual change
year_group= (train.groupby("year"))["count"].sum()
year_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='year',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# There are more bikes rented in 2012 than in 2011, which may indicate that there is an impact of time on the dependent variable.

# %%
#monthly change
month_group= (train.groupby("month"))["count"].sum()
month_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='month',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The change according to month follows the trend found according to season.

# %%
#hourly change expressed in bar graph
hour_group= (train.groupby("hour"))["count"].sum()
hour_group.reset_index(name="total_rentals")
sns.barplot(y='count',x='hour',data=train,palette="colorblind")
plt.show()

# %% [markdown]
# The rush hour is 8 o'clock in the morning and 5 to 6 o'clock in the afternoon.

# %%
#see if there is relation between windspeed and count
sns.jointplot(y='count',x='windspeed',data=train)

# %% [markdown]
# ## Part 2: Find correlation between variables for the regression

# %%
corr = train.corr()
corr.style.background_gradient().set_precision(1)
# Out:
# <style  type="text/css" >
# #T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col1,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col2,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row4_col4,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col5,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col7,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row8_col8,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row9_col9,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row10_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row13_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col1,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row8_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col7{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col2,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col2{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col3{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col4,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row8_col7{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col5,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col8,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col8,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col5{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col14{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col7,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col8{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col9{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row9_col14,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col10{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col5,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row13_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col11{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row9_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row10_col9,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col0{
#             background-color:  #023e62;
#             color:  #f1f1f1;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row10_col1{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row0_col14,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col14,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col14,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row13_col2,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row13_col14{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col2,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col7{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col12{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col4{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col6{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col7{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col8,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row9_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row10_col0{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col9,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col1,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row12_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col13{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col7,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col6{
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row4_col3{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col1,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row13_col1{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row1_col14{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col0{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col1,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col8,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col14,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row3_col4,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col7,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col9,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col10,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row6_col13,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col0,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col5,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row7_col12,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row10_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col2{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col4,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row11_col4{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col5,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row4_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col3,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row5_col11,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row14_col3{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row2_col6,#T_bcdcf9eb_7bf4_11eb_8835_94e979d1ebb0row8_col1{
#             background-

# %% [markdown]
# hour and temp has strongest correlation with the count of bikes. But hour and temp also have significant correlation with each other.

# %%
dataY = train['count'] #target variable
dataX = train.drop(columns=['count'],axis=1) #independent variables

# %%
# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(train,dataY, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
X_train.head()

#convert variables into categories
X_train['season'] = X_train['season'].astype('category')
X_train['hour'] = X_train['hour'].astype('category')
X_train['weekday'] = X_train['weekday'].astype('category')
X_train['month'] = X_train['month'].astype('category')
# Out:
# (7440, 16) (7440,)
# (1861, 16) (1861,)

# %% [markdown]
# ## Part 3: Regression Analysis

# %%
#1st try of regression with all the variables
model_fit = sm.ols(formula="count ~ hour + season + month + weather + temp +windspeed", data=X_train).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.617
# Method:                 Least Squares   F-statistic:                     325.5
# Date:                Wed, 03 Mar 2021   Prob (F-statistic):               0.00
# Time:                        12:47:43   Log-Likelihood:                -44591.
# No. Observations:                7440   AIC:                         8.926e+04
# Df Residuals:                    7402   BIC:                         8.952e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -42.3520      8.006     -5.290      0.000     -58.045     -26.659
# hour[T.1]     -10.3191      7.770     -1.328      0.184     -25.551       4.913
# hour[T.2]     -22.8501      7.932     -2.881      0.004     -38.399      -7.302
# hour[T.3]     -37.7058      8.108     -4.650      0.000     -53.600     -21.812
# hour[T.4]     -36.6914      7.885     -4.653      0.000     -52.148     -21.235
# hour[T.5]     -21.6784      7.745     -2.799      0.005     -36.860      -6.497
# hour[T.6]      30.8055      7.824      3.937      0.000      15.468      46.143
# hour[T.7]     168.8421      7.758     21.765      0.000     153.635     184.049
# hour[T.8]     248.8280      8.197     30.355      0.000     232.759     264.897
# hour[T.9]     170.2504      7.796     21.837      0.000     154.967     185.534
# hour[T.10]    113.6695      7.725     14.714      0.000      98.526     128.813
# hour[T.11]    152.7123      7.668     19.915      0.000     137.681     167.744
# hour[T.12]    178.4080      7.882     22.634      0.000     162.957     193.859
# hour[T.13]    174.3295      7.877     22.133      0.000     158.889     189.770
# hour[T.14]    164.4571      7.753     21.212      0.000     149.259     179.655
# hour[T.15]    173.3136      7.845     22.092      0.000     157.935     188.692
# hour[T.16]    238.0437      7.820     30.441      0.000     222.715     253.373
# hour[T.17]    320.8602      8.190     39.178      0.000     304.806     336.915
# hour[T.18]    299.2024      8.051     37.161      0.000     283.419     314.985
# hour[T.19]    244.6478      7.738     31.617      0.000     229.480     259.816
# hour[T.20]    165.4194      7.686     21.523      0.000     150.353     180.485
# hour[T.21]    118.3605      7.757     15.260      0.000     103.156     133.565
# hour[T.22]     76.1728      7.720      9.867      0.000      61.039      91.306
# hour[T.23]     33.6892      7.776      4.333      0.000      18.447      48.932
# season[T.2]    28.1356      4.647      6.054      0.000      19.026      37.246
# season[T.3]    11.3108      5.826      1.941      0.052      -0.110      22.732
# season[T.4]    47.2969      3.747     12.623      0.000      39.952      54.642
# month[T.2]     12.5940      5.490      2.294      0.022       1.831      23.357
# month[T.3]     17.4355      5.730      3.043      0.002       6.204      28.667
# month[T.4]      6.1912      3.379      1.832      0.067      -0.432      12.814
# month[T.5]     21.3665      3.523      6.064      0.000      14.460      28.273
# month[T.6]      0.5780      4.246      0.136      0.892      -7.745       8.901
# month[T.7]     -5.9555      4.119     -1.446      0.148     -14.030       2.119
# month[T.8]     -2.3090      3.899     -0.592      0.554      -9.951       5.333
# month[T.9]     19.5753      3.538      5.533      0.000      12.640      26.511
# month[T.10]    14.0056      3.971      3.527      0.000       6.222      21.789
# month[T.11]    18.6219      3.358      5.545      0.000      12.038      25.205
# month[T.12]    14.6693      3.457      4.243      0.000       7.892      21.446
# weather       -32.5112      1.786    -18.201      0.000     -36.013     -29.010
# temp            6.2148      0.337     18.468      0.000       5.555       6.874
# windspeed      -0.6914      0.169     -4.094      0.000      -1.023      -0.360
# ==============================================================================
# Omnibus:                      537.328   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              809.007
# Skew:                           0.587   Prob(JB):                    2.12e-176
# Kurtosis:                       4.110   Cond. No.                     2.24e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.98e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Adj. R squared is 0.62 here. Some random variables have high p value or having an insignificant linear relationship to the number of bike get rented

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# %%
# plot the residuals
residualplot = plt.figure(1)
residualplot.set_figheight(8)
residualplot.set_figwidth(12)

residualplot.axes[0] = sns.residplot(model_fitted_y, y_train, 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

residualplot.axes[0].set_title('Residuals vs Fitted')
residualplot.axes[0].set_xlabel('Fitted values')
residualplot.axes[0].set_ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# Seeing heteroskedasticity in the residual plot. The pattern in the residuals plot indicate that this linear regression model is not good.

# %%
#plot the qq plot to find the residule have normal distribution
from statsmodels.graphics.gofplots import ProbPlot

QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# %% [markdown]
# Residuals are not normal distributed since the blue dots are not lying on the straight line. We can conclude that this is not a fitted model.
#
# To improve the model, we next fit the model by taking lograithmic of number of rentals as the dependent variable.

# %%
#2nd try of regression analysis by changing the dependent variable to log
X_train['logCount'] = np.log(X_train['count'])
y_train = X_train['logCount']

X_test['logCount'] = np.log(X_test['count'])
y_test = X_test['logCount']

model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=X_train).fit()
print(model_fit.summary())

# %% [markdown]
# We got higher value in Adj. R squared (=0.79). However, there are still some month variables that have insignificant impact on the dependent variable.

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# %%
#conduct the residule plot
residualplot = plt.figure(1)
residualplot.set_figheight(8)
residualplot.set_figwidth(12)

residualplot.axes[0] = sns.residplot(model_fitted_y, y_train, 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

residualplot.axes[0].set_title('Residuals vs Fitted')
residualplot.axes[0].set_xlabel('Fitted values')
residualplot.axes[0].set_ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# It can be seen in the above graph that this graph has a less uniform pattern than the previous plot.

# %%
#plot the qq plot
from statsmodels.graphics.gofplots import ProbPlot

QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# %% [markdown]
# Seeing a better patten in the residual plot. The points are more normal distributed comparing to that in the last model.

# %%
#Root Mean Squared Logarithmic Error
def rmsle(prediction, actual):
    log1 = np.nan_to_num(np.array([v for v in prediction]))
    log2 = np.nan_to_num(np.array([v for v in actual]))
    calc = (log1 - log2) ** 2
    return np.sqrt(np.mean(calc))

# %%
#Performing the predictions using the fitted model and computing MSE

ypred = model_fit.predict(X_test)
predictions = ypred.values

i=0
for v in predictions:
    if predictions[i]<0:
        predictions[i] = 0
    i = i+1    

RMSLE = rmsle(predictions,y_test)
print(" The Mean Squared error for this model is:",RMSLE)
# Out:
#  The Mean Squared error for this model is: 0.6490832508214429

# %%
# check the model in the test data
plt.figure(figsize=(5, 5))
plt.scatter(predictions,y_test)
plt.legend(["DataPoints"])
plt.plot( [0,8],[0,8], color='red')
plt.legend(["AccuracyLine","DataPoints"])
plt.xlabel('Predictions')
plt.ylabel('test_y')
plt.title('Linear Regression Model')

train.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 11 2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# 12 2011-01-01 12:00:00       1        0           0        1  17.22  21.210
# 13 2011-01-01 13:00:00       1        0           0        2  18.86  22.725
#
#     humidity  windspeed  casual  registered  count  year  month  hour  weekday
# 5         75     6.0032       0           1      1  2011      1     5        5
# 10        76    16.9979      12          24     36  2011      1    10        5
# 11        81    19.0012      26          30     56  2011      1    11        5
# 12        77    19.0012      29          55     84  2011      1    12        5
# 13        72    19.9995      47          47     94  2011      1    13        5

# %% [markdown]
# As in the graph, we can say that the model fit pretty well.

# %% [markdown]
# ## Part 4: Time Series Consideration in the regression analysis

# %% [markdown]
# As a further extension we also include the timeseries impact on the rentals, since the number of rentals increases month by month.
#
# The way we do this is make the month column grow linearly over each month.

# %%
train["month"] = train["datetime"].dt.month

def timeseries_month(df):
    year = df.year
    month = df.month
    if year>2011:
        month = df.month+ 12*(year-2011)
    
    return month

train['month'] = train.apply(timeseries_month,axis=1)
X_train['month'] = X_train.apply(timeseries_month,axis=1)
X_test['month'] = X_test.apply(timeseries_month,axis=1)

# %%
X_train['logCount'] = np.log(X_train['count'])
y_train = X_train['logCount']

X_test['logCount'] = np.log(X_test['count'])
y_test = X_test['logCount']

model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=X_train).fit_regularized()
print(model_fit.params)
# Out:
# Intercept      3.152537
# hour[T.1]     -0.670371
# hour[T.2]     -1.245529
# hour[T.3]     -1.848550
# hour[T.4]     -2.189574
# hour[T.5]     -1.094165
# hour[T.6]      0.090087
# hour[T.7]      1.140642
# hour[T.8]      1.705211
# hour[T.9]      1.528075
# hour[T.10]     1.207668
# hour[T.11]     1.382972
# hour[T.12]     1.569767
# hour[T.13]     1.550417
# hour[T.14]     1.481843
# hour[T.15]     1.536780
# hour[T.16]     1.794663
# hour[T.17]     2.162811
# hour[T.18]     2.050061
# hour[T.19]     1.767559
# hour[T.20]     1.452852
# hour[T.21]     1.200756
# hour[T.22]     0.930553
# hour[T.23]     0.510216
# season[T.2]    0.403199
# season[T.3]    0.310174
# season[T.4]    0.226243
# month          0.041434
# weather       -0.245235
# temp           0.019495
# windspeed     -0.010812
# dtype: float64

# %% [markdown]
# The Adj. R squared is 0.823, which is improved from the last model. We now dont have any insignificant variables as there is no high p value. It is better to consider time change in our model.

# %%
ypred = model_fit.predict(X_test)
predictions = ypred.values

i=0
for v in predictions:
    if predictions[i]<0:
        predictions[i] = 0
    i = i+1    

RMSLE = rmsle(predictions,y_test)
print("RMSLE:",RMSLE)

#test the model in the test data
plt.figure(figsize=(5, 5))
plt.scatter(predictions,y_test)
plt.legend(["DataPoints"])
plt.plot( [0,8],[0,8], color='red')
plt.legend(["AccuracyLine","DataPoints"])
plt.xlabel('Predictions')
plt.ylabel('test_y')
plt.title('Linear Regression Model')
plt.savefig("Overall_Regression_Model")
# Out:
# RMSLE: 0.615704543428738

# %%
from sklearn.linear_model import Ridge
import numpy as np
n_samples, n_features = 10, 5
np.random.seed(0)
y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)
clf = Ridge(alpha=1.0)
clf.fit(X, y) 
Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
# Out:
# Ridge()

# %% [markdown]
# As in the graph, we can say that the model fit pretty well.

# %% [markdown]
# ## Part 5: Analyzing Number of Observations on the run time of regression

# %% [markdown]
# Since the number of rows in the dataset is only about 10000, for analyzing the time taken for regression what we do is concat the dataset to form double, quadraple and even bigger datasets.
#
# We then see how time taken for the regression changes according to the increase in data size

# %%
import time
duplicity = [2,4,6,8,16,32,64]  #Duplicity factor for dataset
time_taken=[]

for dup in duplicity:
    duplist = []
    for i in range(dup):
        duplist.append(X_train)
    result = pd.concat(duplist)
    time1 = time.time()
    model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=result).fit()
    time2 = time.time()
    time_taken.append(time2-time1)

# %%
plt.figure(figsize=(5, 5))
plt.plot(duplicity,time_taken)
plt.xlabel('Data Size increase Factor')
plt.ylabel('Time taken for regression (in seconds)')
plt.title('Regression Model')
# Out:
# Text(0.5, 1.0, 'Regression Model')

# %% [markdown]
# If the dataset increase its size (currently by duplicating the factors of dataset), the time taken for regression will increase.
